# %%
import snow.utils as sf
import pandas as pd
from fbprophet import Prophet

import warnings
warnings.filterwarnings('ignore')
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
financials_df = sf.from_snow(wh='load_wh'
                             ,role='all_data_viewer'
                             ,db='all_data'
                             ,q_kind='user_financials'
                             ,to_df=True)
# Out:
# Using all_data_viewer...
# Established connection.
# Querying load_wh.all_data.postgres
# User_financials data:  ('2016-06-18', 'Secure Parking Melbourne', None, '47024', 0.0, 0.0, 2, 1073, 'Melbourne', 0.0, None, 0.0)
#
# Connection succesfully closed.

# %%
## Convert strings to datetime objects
financials_df.ds = pd.to_datetime(financials_df.ds)
financials_df.head()
# Out:
#           ds                  merchant       rate     uid  \
# 0 2016-06-18  Secure Parking Melbourne       None   47024
# 1 2018-11-21                     Ipoh   20.000000  248594
# 2 2019-03-18                    Aqua S  15.000000  348093
# 3 2018-07-07            Romanos Coffee  10.000000  158538
# 4 2018-08-31                      8Bit  20.000000  192771
#
#    lifetime_transaction_count  lifetime_organic_volume  lifetime_promo_volume  \
# 0                        0.00                      0.0                    2.0
# 1                      111.20                      0.0                    9.0
# 2                        7.15                      0.0                    1.0
# 3                       11.50                      0.0                    1.0
# 4                       90.50                     12.0                    9.0
#
#    sign_up_delta       city  transaction_org_volume  lifetime_aov  \
# 0         1073.0  Melbourne                    0.00           NaN
# 1          212.0     Sydney                    1.00         11.00
# 2           70.0  Melbourne                    7.15          7.15
# 3          324.0  Melbourne                    1.50         11.50
# 4          278.0  Melbourne                    4.50         16.50
#
#    transaction_total_volume
# 0                      0.00
# 1                     11.00
# 2                      7.15
# 3                     11.50
# 4                     16.50

# %% [markdown]
# ### Feature engineering
#
# Now need to derive a
#
#     -> last transaction delta; [tick]
#
#     -> repeat transaction delta; [tick]
#
#     -> progressive single merchant volume; [tick]
#
#     -> progressive organic volume count; [tick]
#
#     -> progressive transaction count; [tick]
#
#     -> promo volume for single transactions; [tick]
#
#     -> progressive merchant count; [tick]
#
#     -> progressive geo_cluster count; [not yet resolved!!]
#
#     -> progressive merchant transaction count. [tick]
#
#     ...

# %%
financials_df.shape[0]
# Out:
# 565978

# %%
transaction_delta = []
repeat_transaction_delta = []

progressive_transaction_count = []
progressive_organic_volume = []

progressive_merchant_count = []

progressive_merchant_volume = []
progressive_merchant_transaction_count = []

single_transaction_promo_volume = []

financials_df = financials_df.drop_duplicates().sort_values(by='ds',ascending=False)

df = financials_df.copy().sort_values(by='ds',ascending=False)

count=0
for i,r in df.iterrows():
    count+=1
    uid = r.uid; merchant = r.merchant; date = r.ds
    
    user_df = df[df.uid==uid]
    prior_df = user_df[user_df.ds<=date]
    shaved_df = prior_df[prior_df.index!=i]
    
    if count % 5000 == 0 or count==5:
        
        zp = zip(single_transaction_promo_volume,
                 progressive_transaction_count,
                 progressive_merchant_count,
                 progressive_merchant_volume,
                 progressive_merchant_transaction_count,
                 progressive_organic_volume,
                 repeat_transaction_delta,
                 transaction_delta)
        
        pd.DataFrame(list(zp),
                     columns=['single_transaction_promo_volume',
                                'prog_transaction_count',
                                'prog_merchant_count',
                                'prog_merchant_volume',
                                'prog_merchant_transaction_count',
                                'prog_organic_volume',
                                'repeat_transaction_delta',
                                'transaction_delta']).to_csv('sequential_features.csv',
                                                            index=False)
        
        print(str(df.shape[0]-count)+' transactions left to process...')
    
    single_transaction_promo_volume += [r.transaction_total_volume - r.transaction_org_volume]

    progressive_transaction_count += [prior_df.shape[0]]
    progressive_merchant_count += [prior_df.merchant.nunique()]
    progressive_organic_volume += [prior_df.transaction_org_volume.sum()]
    
    if shaved_df.shape[0]>0:
        transaction_delta += [(date-list(shaved_df.ds)[0]).days]
    else:
        transaction_delta += [None]
    
    merchant_df = shaved_df[shaved_df.merchant==merchant]
    
    if merchant_df.shape[0]>0:
        repeat_transaction_delta += [(date-list(merchant_df.ds)[0]).days]
    else:
        repeat_transaction_delta += [None]
        
    progressive_merchant_volume += [(merchant_df.transaction_org_volume.sum())]
    progressive_merchant_transaction_count += [merchant_df.shape[0]+1]
    
    
    
financials_df['transaction_promo_volume'] = single_transaction_promo_volume
financials_df['prog_transaction_count'] = progressive_transaction_count
financials_df['prog_merchant_count'] = progressive_merchant_count
financials_df['prog_merchant_volume'] = progressive_merchant_volume
financials_df['prog_merchant_transaction_count'] = progressive_merchant_transaction_count
financials_df['prog_organic_volume'] = progressive_organic_volume
financials_df['repeat_transaction_delta'] = repeat_transaction_delta
financials_df['transaction_delta'] = transaction_delta
# Out:
# 565977 transactions left to process...
# 565976 transactions left to process...
# 565975 transactions left to process...
# 565974 transactions left to process...
# 565973 transactions left to process...
# 565972 transactions left to process...
# 565971 transactions left to process...
# 565970 transactions left to process...
# 565969 transactions left to process...
# 565968 transactions left to process...
# 565967 transactions left to process...
# 565966 transactions left to process...
# 565965 transactions left to process...
# 565964 transactions left to process...
# 565963 transactions left to process...
# 565962 transactions left to process...
# 565961 transactions left to process...
# 565960 transactions left to process...
# 565959 transactions left to process...
# 565958 transactions left to process...
# 565957 transactions left to process...
# 565956 transactions left to process...
# 565955 transactions left to process...
# 565954 transactions left to process...
# 565953 transactions left to process...
# 565952 transactions left to process...
# 565951 transactions left to process...
# 565950 transactions left to process...
# 565949 transactions left to process...
# 565948 transactions left to process...
# 565947 transactions left to process...
# 565946 transactions left to process...
# 565945 transactions left to process...
# 565944 transactions left to process...
# 565943 transactions left to process...
# 565942 transactions left to process...
# 565941 transactions left to process...
# 565940 transactions left to process...
# 565939 transactions left to process...
# 565938 transactions left to process...
# 565937 transactions left to process...
# 565936 transactions left to process...
# 565935 transactions left to process...
# 565934 transactions left to process...
# 565933 transactions left to process...
# 565932 transactions left to process...
# 565931 transactions left to process...
# 565930 transactions left to process...
# 565929 transactions left to process...
# 565928 transactions left to process...
# 565927 transactions left to process...
# 565926 transactions left to process...
# 565925 transactions left to process...
# 565924 transactions left to process...
# 565923 transactions left to process...
# 565922 transactions left to process...
# 565921 transactions left to process...
# 565920 transactions left to process...
# 565919 transactions left to process...
# 565918 transactions left to process...
# 565917 transactions left to process...
# 565916 transactions left to process...
# 565915 transactions left to process...
# 565914 transactions left to process...
# 565913 transactions left to process...
# 565912 transactions left to process...
# 565911 transactions left to process...
# 565910 transactions left to process...
# 565909 transactions left to process...
# 565908 transactions left to process...
# 565907 transactions left to process...
# 565906 transactions left to process...
# 565905 transactions left to process...
# 565904 transactions left to process...
# 565903 transactions left to process...
# 565902 transactions left to process...
# 565901 transactions left to process...
# 565900 transactions left to process...
# 565899 transactions left to process...
# 565898 transactions left to process...
# 565897 transactions left to process...
# 565896 transactions left to process...
# 565895 transactions left to process...
# 565894 transactions left to process...
# 565893 transactions left to process...
# 565892 transactions left to process...
# 565891 transactions left to process...
# 565890 transactions left to process...
# 565889 transactions left to process...
# 565888 transactions left to process...
# 565887 transactions left to process...
# 565886 transactions left to process...
# 565885 transactions left to process...
# 565884 transactions left to process...
# 565883 transactions left to process...
# 565882 transactions left to process...
# 565881 transactions left to process...
# 565880 transactions left to process...
# 565879 transactions left to process...
# 565878 transactions left to process...
# 565877 transactions left to process...
# 565876 transactions left to process...
# 565875 transactions left to process...
# 565874 transactions left to process...
# 565873 transactions left to process...
# 565872 transactions left to process...
# 565871 transactions left to process...
# 565870 transactions left to process...
# 565869 transactions left to process...
# 565868 transactions left to process...
# 565867 transactions left to process...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3042beb0bad0> in <module>
#      21     uid = r.uid; merchant = r.merchant; date = r.ds
#      22
# ---> 23     user_df = df[df.uid==uid]
#      24     prior_df = user_df[user_df.ds<=date]
#      25     shaved_df = prior_df[prior_df.index!=i]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# KeyboardInterrupt:

# %%
progressive_merchant_volume
# Out:
# [229.35]

# %%
progressive_merchant_transaction_count
# Out:
# [36]

# %%
single
